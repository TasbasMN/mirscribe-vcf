# %%
cd ../..
# Out:
# /home/nazif/thesis/mirscribe-vcf
# /home/nazif/.cache/pypoetry/virtualenvs/mirscribe-vcf-8VJm4tPg-py3.10/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
kb = pd.read_csv("data/oncokb/cancerGeneList.tsv", sep="\t")

# Create a dictionary mapping the old column names to the new ones
new_column_names = {
    'Hugo Symbol': 'gene_symbol',
    'Entrez Gene ID': 'entrez_gene_id',
    'GRCh37 Isoform': 'grch37_isoform',
    'GRCh37 RefSeq': 'grch37_refseq',
    'GRCh38 Isoform': 'grch38_isoform',
    'GRCh38 RefSeq': 'grch38_refseq',
    'Is Oncogene': 'is_oncogene',
    'Is Tumor Suppressor Gene': 'is_tumor_suppressor',
    '# of occurrence within resources (Column J-P)': 'occurrence_within_resources',
    'OncoKB Annotated': 'oncokb_annotated',
    'MSK-IMPACT': 'msk_impact',
    'MSK-HEME': 'msk_heme',
    'FOUNDATION ONE': 'foundation_one',
    'FOUNDATION ONE HEME': 'foundation_one_heme',
    'Vogelstein': 'vogelstein',
    'COSMIC CGC (v99)': 'is_cosmic_tier_1',
    'Gene Aliases': 'gene_aliases'
}

# Rename the columns using the dictionary
kb = kb.rename(columns=new_column_names)

kb.head()
# Out:
#   gene_symbol  entrez_gene_id   grch37_isoform   grch37_refseq  \
# 0        ABL1              25  ENST00000318560     NM_005157.4
# 1        AKT1             207  ENST00000349310  NM_001014431.1
# 2         ALK             238  ENST00000389048     NM_004304.4
# 3       AMER1          139285  ENST00000330258     NM_152424.3
# 4         APC             324  ENST00000257430     NM_000038.5
#
#     grch38_isoform   grch38_refseq is_oncogene is_tumor_suppressor  \
# 0  ENST00000318560     NM_005157.4         Yes                  No
# 1  ENST00000349310  NM_001014431.1         Yes                  No
# 2  ENST00000389048     NM_004304.4         Yes                  No
# 3  ENST00000374869     NM_152424.3          No                 Yes
# 4  ENST00000257430     NM_000038.5          No                 Yes
#
#    occurrence_within_resources oncokb_annotated msk_impact msk_heme  \
# 0                            7              Yes        Yes      Yes
# 1                            7              Yes        Yes      Yes
# 2                            7              Yes        Yes      Yes
# 3                            7              Yes        Yes      Yes
# 4                            7              Yes        Yes      Yes
#
#   foundation_one foundation_one_heme vogelstein is_cosmic_tier_1  \
# 0            Yes                 Yes        Yes              Yes
# 1            Yes                 Yes        Yes              Yes
# 2            Yes                 Yes        Yes              Yes
# 3            Yes                 Yes        Yes              Yes
# 4            Yes                 Yes        Yes              Yes
#
#                             gene_aliases
# 0                       ABL, JTK7, c-ABL
# 1        AKT, PKB, PRKBA, RAC, RAC-alpha
# 2                                  CD246
# 3  FAM123B, FLJ39827, RP11-403E24.2, WTX
# 4                         DP2.5, PPP1R46

# %%
ids = (pd.read_csv("data/oncokb/entrez_id_to_ensg.tsv", sep="\t")
       .dropna(how='all')
       .rename(columns={'NCBI Gene ID': 'ncbi_gene_id', 'Ensembl gene ID': 'ensembl_gene_id'})
)

ids.ncbi_gene_id = ids.fillna(0).ncbi_gene_id.astype(int)

kb = kb.merge(ids, left_on="entrez_gene_id", right_on="ncbi_gene_id", how="left")
kb.drop("ncbi_gene_id", axis=1, inplace=True)

# %%
missing_genes = kb[((kb["is_oncogene"] == "Yes") | (kb["is_tumor_suppressor"] == "Yes")) & (kb.ensembl_gene_id.isna())].entrez_gene_id
missing_genes
# Out:
# 826    6955
# 827    6957
# 828    6964
# 829    6965
# Name: entrez_gene_id, dtype: int64

# %% [markdown]
# # checking hgnc if these genes are available

# %%
hgnc = pd.read_csv("data/hgnc/hgnc.tsv", sep="\t")
hgnc[hgnc["NCBI Gene ID"].isin(missing_genes)]
# Out:
#       Approved symbol                Approved name  \
# 39737             TRA  T cell receptor alpha locus
# 39963             TRB   T cell receptor beta locus
# 40091             TRD  T cell receptor delta locus
# 40201             TRG  T cell receptor gamma locus
#
#       MANE Select Ensembl transcript ID (supplied by NCBI) Ensembl gene ID  \
# 39737                                                NaN               NaN
# 39963                                                NaN               NaN
# 40091                                                NaN               NaN
# 40201                                                NaN               NaN
#
#                               Gene group name  NCBI Gene ID  \
# 39737  T cell receptor alpha locus at 14q11.2        6955.0
# 39963      T cell receptor beta locus at 7q34        6957.0
# 40091  T cell receptor delta locus at 14q11.2        6964.0
# 40201     T cell receptor gamma locus at 7p14        6965.0
#
#                       Locus type Enzyme IDs
# 39737  gene with protein product        NaN
# 39963  gene with protein product        NaN
# 40091  gene with protein product        NaN
# 40201  gene with protein product        NaN

# %% [markdown]
# # these genes have no reference in both GRCh37 & 38.

# %%
# drop the missing genes
kb.drop(kb[((kb["is_oncogene"] == "Yes") | (kb["is_tumor_suppressor"] == "Yes")) & (kb.ensembl_gene_id.isna())].index, inplace=True)

# filter cols
cols_to_keep = ['gene_symbol', 'ensembl_gene_id', 'is_oncogene', 'is_tumor_suppressor', 'is_cosmic_tier_1']
kb = kb[cols_to_keep]

# change column types to bool
for column in kb.columns:
    if column.startswith("is_"):
        kb[column] = kb[column].map({"Yes": True, "No": False})

# %%
kb.head()
# Out:
#   gene_symbol  ensembl_gene_id  is_oncogene  is_tumor_suppressor  \
# 0        ABL1  ENSG00000097007         True                False
# 1        AKT1  ENSG00000142208         True                False
# 2         ALK  ENSG00000171094         True                False
# 3       AMER1  ENSG00000184675        False                 True
# 4         APC  ENSG00000134982        False                 True
#
#    is_cosmic_tier_1
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True

# %%
kb.to_csv("data/oncokb/oncokb.csv", index=False)
