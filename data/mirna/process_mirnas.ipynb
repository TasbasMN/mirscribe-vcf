# %%
import pandas as pd
import editdistance

# %%
def parse_fasta(file_path):
    results = []
    
    with open(file_path, 'r') as file:
        sequence = ''
        header = ''
        
        for line in file:
            line = line.strip()
            
            if line.startswith('>'):
                if sequence:
                    results.append((header, sequence))
                    sequence = ''
                
                header = line[1:]
            else:
                sequence += line
        
        if sequence:
            results.append((header, sequence))
    
    return results

def reverse_complement_rna_to_dna(rna_sequence):
    complement = {'A': 'T', 'U': 'A', 'C': 'G', 'G': 'C'}
    reverse_seq = rna_sequence[::-1]
    return ''.join(complement[base] for base in reverse_seq)

def find_least_different_string(original_string, column, cache=None):
    if cache is None:
        cache = {}
    min_distance = float('inf')
    least_different_string = ''
    for sequence in column:
        if sequence in cache:
            distance = cache[sequence]
        else:
            distance = editdistance.eval(original_string, sequence)
            cache[sequence] = distance
        if distance < min_distance:
            min_distance = distance
            least_different_string = sequence
    return least_different_string

# %%
mirbase = parse_fasta('mirbase_22.fa')

#parse the mirbase list by splitting the elements and creating a new list with the desired format
parsed_mirbase = [(parts[0], parts[1], item[1]) for item in mirbase for parts in [item[0].split(' ')]]

mb_df = (pd.DataFrame(parsed_mirbase, columns=['mirna_name', 'mirna_accession', 'sequence'])
         .query('mirna_name.str.startswith("hsa")')
         .assign(sequence= lambda x: x.sequence.apply(reverse_complement_rna_to_dna))
         .sort_values("mirna_accession")
         .reset_index(drop=True)
        )

# %%
renaming_dict = {
    "Mature sequence": "sequence",
    "Family Conservation?": "conservation",
    "MiRBase Accession": "mirna_accession",
    'MiRBase ID': 'mirna_name',
    "miR family": "mirna_family"
}

ts_df = (pd.read_csv('targetscan_mirnas.txt', sep='\t')
         .rename(columns=renaming_dict)
         
         .query('mirna_name.str.startswith("hsa")')
         .drop([ "Species ID", "Seed+m8"], axis=1)
         .iloc[:, [1, 4, 0, 3, 2]]
         .assign(sequence= lambda x: x.sequence.apply(reverse_complement_rna_to_dna))
         .sort_values("mirna_accession")
         .reset_index(drop=True)
         )

ts_df.head()
# Out:
#       mirna_name mirna_accession    mirna_family  conservation  \
# 0  hsa-let-7a-5p    MIMAT0000062  let-7-5p/98-5p             2
# 1  hsa-let-7b-5p    MIMAT0000063  let-7-5p/98-5p             2
# 2  hsa-let-7c-5p    MIMAT0000064  let-7-5p/98-5p             2
# 3  hsa-let-7d-5p    MIMAT0000065  let-7-5p/98-5p             2
# 4  hsa-let-7e-5p    MIMAT0000066  let-7-5p/98-5p             2
#
#                  sequence
# 0  AACTATACAACCTACTACCTCA
# 1  AACCACACAACCTACTACCTCA
# 2  AACCATACAACCTACTACCTCA
# 3  AACTATGCAACCTACTACCTCT
# 4  AACTATACAACCTCCTACCTCA

# %%
# writing conservation values
df = mb_df.merge(ts_df, on=[ "mirna_name" ,'mirna_accession', "sequence"], how='left')

# Create a mask for rows where 'conservation' is NaN
mask = df['conservation'].isna()

# Creating a dictionary from sequence to conservation in targetscan
pair_dict = dict(zip(ts_df['sequence'], ts_df['conservation']))

# For each row in df that has a missing 'conservation' value
for i, row in df.loc[mask].iterrows():
    original_string = row["sequence"]
    target_sequences = ts_df['sequence']
    # Find the least different sequence
    least_different_string = find_least_different_string(original_string, target_sequences)
    # Map the least different string to its conservation value using the pair_dict
    conservation_value = pair_dict.get(least_different_string, None)
    # Update the 'conservation' value in df
    df.at[i, 'conservation'] = conservation_value




# df["mirna_family"] = df["mirna_family"].fillna('not_classified')

# %%
df.isna().sum()
# Out:
# mirna_name           0
# mirna_accession      0
# sequence             0
# mirna_family       142
# conservation         0
# dtype: int64

# %% [markdown]
# # mircarta

# %%
mircarta = pd.read_csv("miRCarta - miRBase family.csv")

## Create a dictionary with precursors as keys and family names as values
precursor_families = {
    precursor.replace("mir", "miR"): family
    for family, precursors in mircarta.set_index('Family')['Precursor'].apply(lambda x: x.split('; ')).to_dict().items()
    for precursor in precursors
}
precursor_families
# Out:
# {'hsa-miR-106a': 'mir-17',
#  'hsa-miR-106b': 'mir-17',
#  'hsa-miR-17': 'mir-17',
#  'hsa-miR-18a': 'mir-17',
#  'hsa-miR-18b': 'mir-17',
#  'hsa-miR-20a': 'mir-17',
#  'hsa-miR-20b': 'mir-17',
#  'hsa-miR-93': 'mir-17',
#  'hsa-let-7a-1': 'let-7',
#  'hsa-let-7a-2': 'let-7',
#  'hsa-let-7a-3': 'let-7',
#  'hsa-let-7b': 'let-7',
#  'hsa-let-7c': 'let-7',
#  'hsa-let-7d': 'let-7',
#  'hsa-let-7e': 'let-7',
#  'hsa-let-7f-1': 'let-7',
#  'hsa-let-7f-2': 'let-7',
#  'hsa-let-7g': 'let-7',
#  'hsa-let-7i': 'let-7',
#  'hsa-miR-98': 'let-7',
#  'hsa-miR-30a': 'mir-30',
#  'hsa-miR-30b': 'mir-30',
#  'hsa-miR-30c-1': 'mir-30',
#  'hsa-miR-30c-2': 'mir-30',
#  'hsa-miR-30d': 'mir-30',
#  'hsa-miR-30e': 'mir-30',
#  'hsa-miR-15a': 'mir-15',
#  'hsa-miR-15b': 'mir-15',
#  'hsa-miR-16-1': 'mir-15',
#  'hsa-miR-16-2': 'mir-15',
#  'hsa-miR-195': 'mir-15',
#  'hsa-miR-181a-1': 'mir-181',
#  'hsa-miR-181a-2': 'mir-181',
#  'hsa-miR-181b-1': 'mir-181',
#  'hsa-miR-181b-2': 'mir-181',
#  'hsa-miR-181c': 'mir-181',
#  'hsa-miR-181d': 'mir-181',
#  'hsa-miR-29a': 'mir-29',
#  'hsa-miR-29b-1': 'mir-29',
#  'hsa-miR-29b-2': 'mir-29',
#  'hsa-miR-29c': 'mir-29',
#  'hsa-miR-19a': 'mir-19',
#  'hsa-miR-19b-1': 'mir-19',
#  'hsa-miR-19b-2': 'mir-19',
#  'hsa-miR-25': 'mir-25',
#  'hsa-miR-92a-1': 'mir-25',
#  'hsa-miR-92a-2': 'mir-25',
#  'hsa-miR-92b': 'mir-25',
#  'hsa-miR-9-1': 'mir-9',
#  'hsa-miR-9-2': 'mir-9',
#  'hsa-miR-9-3': 'mir-9',
#  'hsa-miR-1185-1': 'mir-154',
#  'hsa-miR-1185-2': 'mir-154',
#  'hsa-miR-154': 'mir-154',
#  'hsa-miR-300': 'mir-154',
#  'hsa-miR-323a': 'mir-154',
#  'hsa-miR-323b': 'mir-154',
#  'hsa-miR-369': 'mir-154',
#  'hsa-miR-377': 'mir-154',
#  'hsa-miR-381': 'mir-154',
#  'hsa-miR-382': 'mir-154',
#  'hsa-miR-409': 'mir-154',
#  'hsa-miR-410': 'mir-154',
#  'hsa-miR-487a': 'mir-154',
#  'hsa-miR-487b': 'mir-154',
#  'hsa-miR-494': 'mir-154',
#  'hsa-miR-496': 'mir-154',
#  'hsa-miR-539': 'mir-154',
#  'hsa-miR-655': 'mir-154',
#  'hsa-miR-656': 'mir-154',
#  'hsa-miR-141': 'mir-8',
#  'hsa-miR-200a': 'mir-8',
#  'hsa-miR-200b': 'mir-8',
#  'hsa-miR-200c': 'mir-8',
#  'hsa-miR-429': 'mir-8',
#  'hsa-miR-1283-1': 'mir-515',
#  'hsa-miR-1283-2': 'mir-515',
#  'hsa-miR-515-1': 'mir-515',
#  'hsa-miR-515-2': 'mir-515',
#  'hsa-miR-516a-1': 'mir-515',
#  'hsa-miR-516a-2': 'mir-515',
#  'hsa-miR-516b-1': 'mir-515',
#  'hsa-miR-516b-2': 'mir-515',
#  'hsa-miR-517a': 'mir-515',
#  'hsa-miR-517b': 'mir-515',
#  'hsa-miR-517c': 'mir-515',
#  'hsa-miR-518a-1': 'mir-515',
#  'hsa-miR-518a-2': 'mir-515',
#  'hsa-miR-518b': 'mir-515',
#  'hsa-miR-518c': 'mir-515',
#  'hsa-miR-518d': 'mir-515',
#  'hsa-miR-518e': 'mir-515',
#  'hsa-miR-518f': 'mir-515',
#  'hsa-miR-519a-1': 'mir-515',
#  'hsa-miR-519a-2': 'mir-515',
#  'hsa-miR-519b': 'mir-515',
#  'hsa-miR-519c': 'mir-515',
#  'hsa-miR-519d': 'mir-515',
#  'hsa-miR-519e': 'mir-515',
#  'hsa-miR-520a': 'mir-515',
#  'hsa-miR-520b': 'mir-515',
#  'hsa-miR-520c': 'mir-515',
#  'hsa-miR-520d': 'mir-515',
#  'hsa-miR-520e': 'mir-515',
#  'hsa-miR-520f': 'mir-515',
#  'hsa-miR-520g': 'mir-515',
#  'hsa-miR-520h': 'mir-515',
#  'hsa-miR-521-1': 'mir-515',
#  'hsa-miR-521-2': 'mir-515',
#  'hsa-miR-522': 'mir-515',
#  'hsa-miR-523': 'mir-515',
#  'hsa-miR-524': 'mir-515',
#  'hsa-miR-525': 'mir-515',
#  'hsa-miR-526a-1': 'mir-515',
#  'hsa-miR-526a-2': 'mir-515',
#  'hsa-miR-526b': 'mir-515',
#  'hsa-miR-527': 'mir-515',
#  'hsa-miR-124-1': 'mir-124',
#  'hsa-miR-124-2': 'mir-124',
#  'hsa-miR-124-3': 'mir-124',
#  'hsa-miR-7-1': 'mir-7',
#  'hsa-miR-7-2': 'mir-7',
#  'hsa-miR-7-3': 'mir-7',
#  'hsa-miR-103a-1': 'mir-103',
#  'hsa-miR-103a-2': 'mir-103',
#  'hsa-miR-103b-1': 'mir-103',
#  'hsa-miR-103b-2': 'mir-103',
#  'hsa-miR-107': 'mir-103',
#  'hsa-miR-218-1': 'mir-218',
#  'hsa-miR-218-2': 'mir-218',
#  'hsa-miR-23a': 'mir-23',
#  'hsa-miR-23b': 'mir-23',
#  'hsa-miR-135a-1': 'mir-135',
#  'hsa-miR-135a-2': 'mir-135',
#  'hsa-miR-135b': 'mir-135',
#  'hsa-miR-133a-1': 'mir-133',
#  'hsa-miR-133a-2': 'mir-133',
#  'hsa-miR-133b': 'mir-133',
#  'hsa-miR-196a-1': 'mir-196',
#  'hsa-miR-196a-2': 'mir-196',
#  'hsa-miR-196b': 'mir-196',
#  'hsa-miR-100': 'mir-10',
#  'hsa-miR-10a': 'mir-10',
#  'hsa-miR-10b': 'mir-10',
#  'hsa-miR-125a': 'mir-10',
#  'hsa-miR-125b-1': 'mir-10',
#  'hsa-miR-125b-2': 'mir-10',
#  'hsa-miR-99a': 'mir-10',
#  'hsa-miR-99b': 'mir-10',
#  'hsa-miR-130a': 'mir-130',
#  'hsa-miR-130b': 'mir-130',
#  'hsa-miR-301a': 'mir-130',
#  'hsa-miR-301b': 'mir-130',
#  'hsa-miR-27a': 'mir-27',
#  'hsa-miR-27b': 'mir-27',
#  'hsa-miR-1-1': 'mir-1',
#  'hsa-miR-1-2': 'mir-1',
#  'hsa-miR-206': 'mir-1',
#  'hsa-miR-34a': 'mir-34',
#  'hsa-miR-34b': 'mir-34',
#  'hsa-miR-34c': 'mir-34',
#  'hsa-miR-199a-1': 'mir-199',
#  'hsa-miR-199a-2': 'mir-199',
#  'hsa-miR-199b': 'mir-199',
#  'hsa-miR-24-1': 'mir-24',
#  'hsa-miR-24-2': 'mir-24',
#  'hsa-miR-204': 'mir-204',
#  'hsa-miR-211': 'mir-204',
#  'hsa-miR-26a-1': 'mir-26',
#  'hsa-miR-26a-2': 'mir-26',
#  'hsa-miR-26b': 'mir-26',
#  'hsa-miR-219a-1': 'mir-219',
#  'hsa-miR-219a-2': 'mir-219',
#  'hsa-miR-219b': 'mir-219',
#  'hsa-miR-101-1': 'mir-101',
#  'hsa-miR-101-2': 'mir-101',
#  'hsa-miR-128-1': 'mir-128',
#  'hsa-miR-128-2': 'mir-128',
#  'hsa-miR-153-1': 'mir-153',
#  'hsa-miR-153-2': 'mir-153',
#  'hsa-miR-221': 'mir-221',
#  'hsa-miR-222': 'mir-221',
#  'hsa-miR-22': 'mir-22',
#  'hsa-miR-216a': 'mir-216',
#  'hsa-miR-216b': 'mir-216',
#  'hsa-miR-194-1': 'mir-194',
#  'hsa-miR-194-2': 'mir-194',
#  'hsa-miR-148a': 'mir-148',
#  'hsa-miR-148b': 'mir-148',
#  'hsa-miR-152': 'mir-148',
#  'hsa-miR-151a': 'mir-28',
#  'hsa-miR-151b': 'mir-28',
#  'hsa-miR-28': 'mir-28',
#  'hsa-miR-205': 'mir-205',
#  'hsa-miR-184': 'mir-184',
#  'hsa-miR-21': 'mir-21',
#  'hsa-miR-365a': 'mir-365',
#  'hsa-miR-365b': 'mir-365',
#  'hsa-miR-214': 'mir-214',
#  'hsa-miR-3120': 'mir-214',
#  'hsa-miR-192': 'mir-192',
#  'hsa-miR-215': 'mir-192',
#  'hsa-miR-31': 'mir-31',
#  'hsa-miR-132': 'mir-132',
#  'hsa-miR-212': 'mir-132',
#  'hsa-miR-183': 'mir-183',
#  'hsa-miR-223': 'mir-223',
#  'hsa-miR-371a': 'mir-290',
#  'hsa-miR-371b': 'mir-290',
#  'hsa-miR-372': 'mir-290',
#  'hsa-miR-32': 'mir-32',
#  'hsa-miR-33a': 'mir-33',
#  'hsa-miR-33b': 'mir-33',
#  'hsa-miR-302a': 'mir-302',
#  'hsa-miR-302b': 'mir-302',
#  'hsa-miR-302c': 'mir-302',
#  'hsa-miR-302d': 'mir-302',
#  'hsa-miR-302f': 'mir-302',
#  'hsa-miR-96': 'mir-96',
#  'hsa-miR-129-1': 'mir-129',
#  'hsa-miR-129-2': 'mir-129',
#  'hsa-miR-105-1': 'mir-105',
#  'hsa-miR-105-2': 'mir-105',
#  'hsa-miR-138-1': 'mir-138',
#  'hsa-miR-138-2': 'mir-138',
#  'hsa-miR-190a': 'mir-190',
#  'hsa-miR-190b': 'mir-190',
#  'hsa-miR-217': 'mir-217',
#  'hsa-miR-187': 'mir-187',
#  'hsa-miR-145': 'mir-145',
#  'hsa-miR-127': 'mir-127',
#  'hsa-miR-193a': 'mir-193',
#  'hsa-miR-193b': 'mir-193',
#  'hsa-miR-142': 'mir-142',
#  'hsa-miR-140': 'mir-140',
#  'hsa-miR-210': 'mir-210',
#  'hsa-miR-224': 'mir-224',
#  'hsa-miR-198': 'mir-198',
#  'hsa-miR-376a-1': 'mir-368',
#  'hsa-miR-376a-2': 'mir-368',
#  'hsa-miR-376b': 'mir-368',
#  'hsa-miR-376c': 'mir-368',
#  'hsa-miR-144': 'mir-144',
#  'hsa-miR-143': 'mir-143',
#  'hsa-miR-122': 'mir-122',
#  'hsa-miR-3591': 'mir-122',
#  'hsa-miR-338': 'mir-338',
#  'hsa-miR-1264': 'mir-95',
#  'hsa-miR-421': 'mir-95',
#  'hsa-miR-545': 'mir-95',
#  'hsa-miR-95': 'mir-95',
#  'hsa-miR-136': 'mir-136',
#  'hsa-miR-146a': 'mir-146',
#  'hsa-miR-146b': 'mir-146',
#  'hsa-miR-147a': 'mir-147',
#  'hsa-miR-147b': 'mir-147',
#  'hsa-miR-137': 'mir-137',
#  'hsa-miR-203a': 'mir-203',
#  'hsa-miR-203b': 'mir-203',
#  'hsa-miR-186': 'mir-186',
#  'hsa-miR-329-1': 'mir-329',
#  'hsa-miR-329-2': 'mir-329',
#  'hsa-miR-495': 'mir-329',
#  'hsa-miR-543': 'mir-329',
#  'hsa-miR-489': 'mir-489',
#  'hsa-miR-134': 'mir-134',
#  'hsa-miR-188': 'mir-188',
#  'hsa-miR-532': 'mir-188',
#  'hsa-miR-660': 'mir-188',
#  'hsa-miR-375': 'mir-375',
#  'hsa-miR-126': 'mir-126',
#  'hsa-miR-182': 'mir-182',
#  'hsa-miR-139': 'mir-139',
#  'hsa-miR-202': 'mir-202',
#  'hsa-miR-197': 'mir-197',
#  'hsa-miR-1197': 'mir-379',
#  'hsa-miR-379': 'mir-379',
#  'hsa-miR-380': 'mir-379',
#  'hsa-miR-411': 'mir-379',
#  'hsa-miR-758': 'mir-379',
#  'hsa-miR-450a-1': 'mir-450',
#  'hsa-miR-450a-2': 'mir-450',
#  'hsa-miR-450b': 'mir-450',
#  'hsa-miR-455': 'mir-455',
#  'hsa-miR-506': 'mir-506',
#  'hsa-miR-507': 'mir-506',
#  'hsa-miR-508': 'mir-506',
#  'hsa-miR-509-1': 'mir-506',
#  'hsa-miR-509-2': 'mir-506',
#  'hsa-miR-509-3': 'mir-506',
#  'hsa-miR-510': 'mir-506',
#  'hsa-miR-511': 'mir-506',
#  'hsa-miR-512-1': 'mir-506',
#  'hsa-miR-512-2': 'mir-506',
#  'hsa-miR-513a-1': 'mir-506',
#  'hsa-miR-513a-2': 'mir-506',
#  'hsa-miR-513b': 'mir-506',
#  'hsa-miR-513c': 'mir-506',
#  'hsa-miR-514a-1': 'mir-506',
#  'hsa-miR-514a-2': 'mir-506',
#  'hsa-miR-514a-3': 'mir-506',
#  'hsa-miR-514b': 'mir-506',
#  'hsa-miR-449a': 'mir-449',
#  'hsa-miR-449b': 'mir-449',
#  'hsa-miR-449c': 'mir-449',
#  'hsa-miR-383': 'mir-383',
#  'hsa-miR-363': 'mir-363',
#  'hsa-miR-500a': 'mir-500',
#  'hsa-miR-500b': 'mir-500',
#  'hsa-miR-501': 'mir-500',
#  'hsa-miR-502': 'mir-500',
#  'hsa-miR-431': 'mir-431',
#  'hsa-miR-326': 'mir-326',
#  'hsa-miR-325': 'mir-325',
#  'hsa-miR-451a': 'mir-451',
#  'hsa-miR-451b': 'mir-451',
#  'hsa-miR-448': 'mir-448',
#  'hsa-miR-155': 'mir-155',
#  'hsa-miR-296': 'mir-296',
#  'hsa-miR-367': 'mir-367',
#  'hsa-miR-320a': 'mir-320',
#  'hsa-miR-320b-1': 'mir-320',
#  'hsa-miR-320b-2': 'mir-320',
#  'hsa-miR-320c-1': 'mir-320',
#  'hsa-miR-320c-2': 'mir-320',
#  'hsa-miR-320d-1': 'mir-320',
#  'hsa-miR-320d-2': 'mir-320',
#  'hsa-miR-320e': 'mir-320',
#  'hsa-miR-424': 'mir-322',
#  'hsa-miR-324': 'mir-324',
#  'hsa-miR-370': 'mir-370',
#  'hsa-miR-378a': 'mir-378',
#  'hsa-miR-378b': 'mir-378',
#  'hsa-miR-378d-1': 'mir-378',
#  'hsa-miR-378d-2': 'mir-378',
#  'hsa-miR-378e': 'mir-378',
#  'hsa-miR-361': 'mir-361',
#  'hsa-miR-499a': 'mir-499',
#  'hsa-miR-454': 'mir-454',
#  'hsa-miR-433': 'mir-433',
#  'hsa-miR-208a': 'mir-208',
#  'hsa-miR-208b': 'mir-208',
#  'hsa-miR-483': 'mir-483',
#  'hsa-miR-503': 'mir-503',
#  'hsa-miR-542': 'mir-542',
#  'hsa-miR-299': 'mir-299',
#  'hsa-miR-346': 'mir-346',
#  'hsa-miR-345': 'mir-345',
#  'hsa-miR-342': 'mir-342',
#  'hsa-miR-340': 'mir-340',
#  'hsa-miR-412': 'mir-412',
#  'hsa-miR-339': 'mir-339',
#  'hsa-miR-191': 'mir-191',
#  'hsa-miR-337': 'mir-337',
#  'hsa-miR-335': 'mir-335',
#  'hsa-miR-150': 'mir-150',
#  'hsa-miR-331': 'mir-331',
#  'hsa-miR-330': 'mir-330',
#  'hsa-miR-485': 'mir-485',
#  'hsa-miR-185': 'mir-185',
#  'hsa-miR-328': 'mir-328',
#  'hsa-miR-297': 'mir-297',
#  'hsa-miR-298': 'mir-298',
#  'hsa-miR-362': 'mir-362',
#  'hsa-miR-432': 'mir-432',
#  'hsa-miR-541': 'mir-541',
#  'hsa-miR-505': 'mir-505',
#  'hsa-miR-484': 'mir-484',
#  'hsa-miR-486-1': 'mir-486',
#  'hsa-miR-486-2': 'mir-486',
#  'hsa-miR-490': 'mir-490',
#  'hsa-miR-493': 'mir-493',
#  'hsa-miR-497': 'mir-497',
#  'hsa-miR-425': 'mir-425',
#  'hsa-miR-149': 'mir-149',
#  'hsa-miR-452': 'mir-452',
#  'hsa-miR-374a': 'mir-374',
#  'hsa-miR-374b': 'mir-374',
#  'hsa-miR-374c': 'mir-374',
#  'hsa-miR-384': 'mir-384',
#  'hsa-miR-664a': 'mir-664',
#  'hsa-miR-664b': 'mir-664',
#  'hsa-miR-466': 'mir-467',
#  'hsa-miR-548a-1': 'mir-548',
#  'hsa-miR-548a-2': 'mir-548',
#  'hsa-miR-548a-3': 'mir-548',
#  'hsa-miR-548aa-1': 'mir-548',
#  'hsa-miR-548aa-2': 'mir-548',
#  'hsa-miR-548ab': 'mir-548',
#  'hsa-miR-548ac': 'mir-548',
#  'hsa-miR-548ad': 'mir-548',
#  'hsa-miR-548ae-1': 'mir-548',
#  'hsa-miR-548ae-2': 'mir-548',
#  'hsa-miR-548ag-1': 'mir-548',
#  'hsa-miR-548ag-2': 'mir-548',
#  'hsa-miR-548ah': 'mir-548',
#  'hsa-miR-548ai': 'mir-548',
#  'hsa-miR-548aj-1': 'mir-548',
#  'hsa-miR-548aj-2': 'mir-548',
#  'hsa-miR-548ak': 'mir-548',
#  'hsa-miR-548al': 'mir-548',
#  'hsa-miR-548am': 'mir-548',
#  'hsa-miR-548an': 'mir-548',
#  'hsa-miR-548ao': 'mir-548',
#  'hsa-miR-548ap': 'mir-548',
#  'hsa-miR-548aq': 'mir-548',
#  'hsa-miR-548ar': 'mir-548',
#  'hsa-miR-548as': 'mir-548',
#  'hsa-miR-548at': 'mir-548',
#  'hsa-miR-548au': 'mir-548',
#  'hsa-miR-548av': 'mir-548',
#  'hsa-miR-548aw': 'mir-548',
#  'hsa-miR-548ax': 'mir-548',
#  'hsa-miR-548ay': 'mir-548',
#  'hsa-miR-548az': 'mir-548',
#  'hsa-miR-548b': 'mir-548',
#  'hsa-miR-548ba': 'mir-548',
#  'hsa-miR-548bb': 'mir-548',
#  'hsa-miR-548c': 'mir-548',
#  'hsa-miR-548d-1': 'mir-548',
#  'hsa-miR-548d-2': 'mir-548',
#  'hsa-miR-548e': 'mir-548',
#  'hsa-miR-548f-1': 'mir-548',
#  'hsa-miR-548f-2': 'mir-548',
#  'hsa-miR-548f-3': 'mir-548',
#  'hsa-miR-548f-4': 'mir-548',
#  'hsa-miR-548f-5': 'mir-548',
#  'hsa-miR-548g': 'mir-548',
#  'hsa-miR-548h-1': 'mir-548',
#  'hsa-miR-548h-2': 'mir-548',
#  'hsa-miR-548h-3': 'mir-548',
#  'hsa-miR-548h-4': 'mir-548',
#  'hsa-miR-548h-5': 'mir-548',
#  'hsa-miR-548i-1': 'mir-548',
#  'hsa-miR-548i-2': 'mir-548',
#  'hsa-miR-548i-3': 'mir-548',
#  'hsa-miR-548i-4': 'mir-548',
#  'hsa-miR-548j': 'mir-548',
#  'hsa-miR-548k': 'mir-548',
#  'hsa-miR-548l': 'mir-548',
#  'hsa-miR-548m': 'mir-548',
#  'hsa-miR-548n': 'mir-548',
#  'hsa-miR-548o-2': 'mir-548',
#  'hsa-miR-548p': 'mir-548',
#  'hsa-miR-548q': 'mir-548',
#  'hsa-miR-548s': 'mir-548',
#  'hsa-miR-548t': 'mir-548',
#  'hsa-miR-548u': 'mir-548',
#  'hsa-miR-548v': 'mir-548',
#  'hsa-miR-548w': 'mir-548',
#  'hsa-miR-548x': 'mir-548',
#  'hsa-miR-548x-2': 'mir-548',
#  'hsa-miR-548y': 'mir-548',
#  'hsa-miR-548z': 'mir-548',
#  'hsa-miR-570': 'mir-548',
#  'hsa-miR-579': 'mir-548',
#  'hsa-miR-603': 'mir-548',
#  'hsa-miR-488': 'mir-488',
#  'hsa-miR-491': 'mir-491',
#  'hsa-miR-423': 'mir-423',
#  'hsa-miR-652': 'mir-652',
#  'hsa-miR-550a-1': 'mir-550',
#  'hsa-miR-550a-2': 'mir-550',
#  'hsa-miR-550a-3': 'mir-550',
#  'hsa-miR-550b-1': 'mir-550',
#  'hsa-miR-550b-2': 'mir-550',
#  'hsa-miR-592': 'mir-592',
#  'hsa-miR-615': 'mir-615',
#  'hsa-miR-802': 'mir-802',
#  'hsa-miR-770': 'mir-770',
#  'hsa-miR-668': 'mir-668',
#  'hsa-miR-671': 'mir-671',
#  'hsa-miR-551a': 'mir-551',
#  'hsa-miR-551b': 'mir-551',
#  'hsa-miR-675': 'mir-675',
#  'hsa-miR-888': 'mir-743',
#  'hsa-miR-890': 'mir-743',
#  'hsa-miR-892a': 'mir-743',
#  'hsa-miR-892b': 'mir-743',
#  'hsa-miR-892c': 'mir-743',
#  'hsa-miR-941-1': 'mir-941',
#  'hsa-miR-941-2': 'mir-941',
#  'hsa-miR-941-3': 'mir-941',
#  'hsa-miR-941-4': 'mir-941',
#  'hsa-miR-941-5': 'mir-941',
#  'hsa-miR-873': 'mir-873',
#  'hsa-miR-877': 'mir-877',
#  'hsa-miR-598': 'mir-598',
#  'hsa-miR-760': 'mir-760',
#  'hsa-miR-708': 'mir-708',
#  'hsa-miR-874': 'mir-874',
#  'hsa-miR-665': 'mir-665',
#  'hsa-miR-568': 'mir-568',
#  'hsa-miR-654': 'mir-654',
#  'hsa-miR-582': 'mir-582',
#  'hsa-miR-590': 'mir-590',
#  'hsa-miR-574': 'mir-574',
#  'hsa-miR-891a': 'mir-891',
#  'hsa-miR-891b': 'mir-891',
#  'hsa-miR-875': 'mir-875',
#  'hsa-miR-876': 'mir-876',
#  'hsa-miR-744': 'mir-744',
#  'hsa-miR-653': 'mir-653',
#  'hsa-miR-544a': 'mir-544',
#  'hsa-miR-544b': 'mir-544',
#  'hsa-miR-504': 'mir-504',
#  'hsa-miR-1224': 'mir-1224',
#  'hsa-miR-1226': 'mir-1226',
#  'hsa-miR-1225': 'mir-1225',
#  'hsa-miR-1227': 'mir-1227',
#  'hsa-miR-1302-1': 'mir-1302',
#  'hsa-miR-1302-10': 'mir-1302',
#  'hsa-miR-1302-11': 'mir-1302',
#  'hsa-miR-1302-2': 'mir-1302',
#  'hsa-miR-1302-3': 'mir-1302',
#  'hsa-miR-1302-4': 'mir-1302',
#  'hsa-miR-1302-5': 'mir-1302',
#  'hsa-miR-1302-6': 'mir-1302',
#  'hsa-miR-1302-7': 'mir-1302',
#  'hsa-miR-1302-8': 'mir-1302',
#  'hsa-miR-1302-9': 'mir-1302',
#  'hsa-miR-650': 'mir-650',
#  'hsa-miR-663a': 'mir-663',
#  'hsa-miR-663b': 'mir-663',
#  'hsa-miR-498': 'mir-498',
#  'hsa-miR-612': 'mir-612',
#  'hsa-miR-661': 'mir-661',
#  'hsa-miR-581': 'mir-581',
#  'hsa-miR-586': 'mir-586',
#  'hsa-miR-642a': 'mir-642',
#  'hsa-miR-642b': 'mir-642',
#  'hsa-miR-938': 'mir-938',
#  'hsa-miR-549a': 'mir-549',
#  'hsa-miR-676': 'mir-676',
#  'hsa-miR-626': 'mir-626',
#  'hsa-miR-556': 'mir-556',
#  'hsa-miR-648': 'mir-648',
#  'hsa-miR-578': 'mir-578',
#  'hsa-miR-651': 'mir-651',
#  'hsa-miR-597': 'mir-597',
#  'hsa-miR-607': 'mir-607',
#  'hsa-miR-583': 'mir-583',
#  'hsa-miR-1271': 'mir-1271',
#  'hsa-miR-600': 'mir-600',
#  'hsa-miR-638': 'mir-638',
#  'hsa-miR-553': 'mir-553',
#  'hsa-miR-643': 'mir-643',
#  'hsa-miR-939': 'mir-939',
#  'hsa-miR-662': 'mir-662',
#  'hsa-miR-576': 'mir-576',
#  'hsa-miR-640': 'mir-640',
#  'hsa-miR-920': 'mir-920',
#  'hsa-miR-589': 'mir-589',
#  'hsa-miR-657': 'mir-657',
#  'hsa-miR-492': 'mir-492',
#  'hsa-miR-373': 'mir-373',
#  'hsa-miR-552': 'mir-552',
#  'hsa-miR-599': 'mir-599',
#  'hsa-miR-593': 'mir-593',
#  'hsa-miR-933': 'mir-933',
#  'hsa-miR-1255a': 'mir-1255',
#  'hsa-miR-1255b-1': 'mir-1255',
#  'hsa-miR-1255b-2': 'mir-1255',
#  'hsa-miR-616': 'mir-616',
#  'hsa-miR-631': 'mir-631',
#  'hsa-miR-942': 'mir-942',
#  'hsa-miR-562': 'mir-562',
#  'hsa-miR-924': 'mir-924',
#  'hsa-miR-889': 'mir-889',
#  'hsa-miR-580': 'mir-580',
#  'hsa-miR-609': 'mir-609',
#  'hsa-miR-936': 'mir-936',
#  'hsa-miR-563': 'mir-563',
#  'hsa-miR-557': 'mir-557',
#  'hsa-miR-601': 'mir-601',
#  'hsa-miR-624': 'mir-624',
#  'hsa-miR-636': 'mir-636',
#  'hsa-miR-632': 'mir-632',
#  'hsa-miR-605': 'mir-605',
#  'hsa-miR-628': 'mir-628',
#  'hsa-miR-577': 'mir-577',
#  'hsa-miR-1306': 'mir-1306',
#  'hsa-miR-885': 'mir-885',
#  'hsa-miR-584': 'mir-584',
#  'hsa-miR-625': 'mir-625',
#  'hsa-miR-569': 'mir-569',
#  'hsa-miR-922': 'mir-922',
#  'hsa-miR-572': 'mir-572',
#  'hsa-miR-558': 'mir-558',
#  'hsa-miR-611': 'mir-611',
#  'hsa-miR-940': 'mir-940',
#  'hsa-miR-944': 'mir-944',
#  'hsa-miR-934': 'mir-934',
#  'hsa-miR-765': 'mir-765',
#  'hsa-miR-633': 'mir-633',
#  'hsa-miR-649': 'mir-649',
#  'hsa-miR-422a': 'mir-422',
#  'hsa-miR-639': 'mir-639',
#  'hsa-miR-627': 'mir-627',
#  'hsa-miR-554': 'mir-554',
#  'hsa-miR-767': 'mir-767',
#  'hsa-miR-618': 'mir-618',
#  'hsa-miR-887': 'mir-887',
#  'hsa-miR-567': 'mir-567',
#  'hsa-miR-644a': 'mir-644',
#  'hsa-miR-619': 'mir-619',
#  'hsa-miR-1307': 'mir-1307',
#  'hsa-miR-1285-1': 'mir-1285',
#  'hsa-miR-1285-2': 'mir-1285',
#  'hsa-miR-937': 'mir-937',
#  'hsa-miR-573': 'mir-573',
#  'hsa-miR-604': 'mir-604',
#  'hsa-miR-587': 'mir-587',
#  'hsa-miR-1244-1': 'mir-1244',
#  'hsa-miR-1244-2': 'mir-1244',
#  'hsa-miR-1244-3': 'mir-1244',
#  'hsa-miR-1244-4': 'mir-1244',
#  'hsa-miR-566': 'mir-566',
#  'hsa-miR-1233-1': 'mir-1233',
#  'hsa-miR-1233-2': 'mir-1233',
#  'hsa-miR-1273a': 'mir-1273',
#  'hsa-miR-1273d': 'mir-1273',
#  'hsa-miR-1273e': 'mir-1273',
#  'hsa-miR-1273f': 'mir-1273',
#  'hsa-miR-1273g': 'mir-1273',
#  'hsa-miR-555': 'mir-555',
#  'hsa-miR-1297': 'mir-1297',
#  'hsa-miR-1237': 'mir-1237',
#  'hsa-miR-575': 'mir-575',
#  'hsa-miR-1282': 'mir-1282',
#  'hsa-miR-1324': 'mir-1324',
#  'hsa-miR-613': 'mir-613',
#  'hsa-miR-1278': 'mir-1278',
#  'hsa-miR-1184-1': 'mir-1184',
#  'hsa-miR-1184-2': 'mir-1184',
#  'hsa-miR-1184-3': 'mir-1184',
#  'hsa-miR-1256': 'mir-1256',
#  'hsa-miR-1262': 'mir-1262',
#  'hsa-miR-1207': 'mir-1207',
#  'hsa-miR-637': 'mir-637',
#  'hsa-miR-1298': 'mir-1298',
#  'hsa-miR-1291': 'mir-1291',
#  'hsa-miR-634': 'mir-634',
#  'hsa-miR-1178': 'mir-1178',
#  'hsa-miR-1294': 'mir-1294',
#  'hsa-miR-1284': 'mir-1284',
#  'hsa-miR-646': 'mir-646',
#  'hsa-miR-935': 'mir-935',
#  'hsa-miR-1303': 'mir-1303',
#  'hsa-miR-1205': 'mir-1205',
#  'hsa-miR-1290': 'mir-1290',
#  'hsa-miR-1253': 'mir-1253',
#  'hsa-miR-564': 'mir-564',
#  'hsa-miR-1202': 'mir-1202',
#  'hsa-miR-1254-1': 'mir-1254',
#  'hsa-miR-1254-2': 'mir-1254',
#  'hsa-miR-1266': 'mir-1266',
#  'hsa-miR-1323': 'mir-1323',
#  'hsa-miR-622': 'mir-622',
#  'hsa-miR-1245a': 'mir-1245',
#  'hsa-miR-1245b': 'mir-1245',
#  'hsa-miR-1251': 'mir-1251',
#  'hsa-miR-1248': 'mir-1248',
#  'hsa-miR-561': 'mir-561',
#  'hsa-miR-762': 'mir-762',
#  'hsa-miR-1299': 'mir-1299',
#  'hsa-miR-1289-1': 'mir-1289',
#  'hsa-miR-1289-2': 'mir-1289',
#  'hsa-miR-1246': 'mir-1246',
#  'hsa-miR-1208': 'mir-1208',
#  'hsa-miR-621': 'mir-621',
#  'hsa-miR-1179': 'mir-1179',
#  'hsa-miR-1203': 'mir-1203',
#  'hsa-miR-1206': 'mir-1206',
#  'hsa-miR-1267': 'mir-1267',
#  'hsa-miR-591': 'mir-591',
#  'hsa-miR-658': 'mir-658',
#  'hsa-miR-1272': 'mir-1272',
#  'hsa-miR-1827': 'mir-1827',
#  'hsa-miR-614': 'mir-614',
#  'hsa-miR-1296': 'mir-1296',
#  'hsa-miR-595': 'mir-595',
#  'hsa-miR-1276': 'mir-1276',
#  'hsa-miR-630': 'mir-630',
#  'hsa-miR-559': 'mir-559',
#  'hsa-miR-645': 'mir-645',
#  'hsa-miR-302e': 'mir-302_2',
#  'hsa-miR-1288': 'mir-1288',
#  'hsa-miR-610': 'mir-610',
#  'hsa-miR-635': 'mir-635',
#  'hsa-miR-1322': 'mir-1322',
#  'hsa-miR-1181': 'mir-1181',
#  'hsa-miR-1249': 'mir-1249',
#  'hsa-miR-1183': 'mir-1183',
#  'hsa-miR-1247': 'mir-1247',
#  'hsa-miR-1825': 'mir-1825',
#  'hsa-miR-1204': 'mir-1204',
#  'hsa-miR-617': 'mir-617',
#  'hsa-miR-1182': 'mir-1182',
#  'hsa-miR-1275': 'mir-1275',
#  'hsa-miR-1292': 'mir-1292',
#  'hsa-miR-1295a': 'mir-1295',
#  'hsa-miR-766': 'mir-766',
#  'hsa-miR-641': 'mir-641',
#  'hsa-miR-588': 'mir-588',
#  'hsa-miR-1286': 'mir-1286',
#  'hsa-miR-1258': 'mir-1258',
#  'hsa-miR-1263': 'mir-1263',
#  'hsa-miR-1265': 'mir-1265',
#  'hsa-miR-1236': 'mir-1236',
#  'hsa-miR-943': 'mir-943',
#  'hsa-miR-1293': 'mir-1293',
#  'hsa-miR-1281': 'mir-1281',
#  'hsa-miR-1250': 'mir-1250',
#  'hsa-miR-759': 'mir-759',
#  'hsa-miR-764': 'mir-764',
#  'hsa-miR-761': 'mir-761',
#  'hsa-miR-1193': 'mir-1193',
#  'hsa-miR-718': 'mir-718',
#  'hsa-miR-1287': 'mir-1287',
#  'hsa-miR-769': 'mir-769',
#  'hsa-miR-670': 'mir-670',
#  'hsa-miR-1301': 'mir-1301',
#  'hsa-miR-711': 'mir-711',
#  'hsa-miR-571': 'mir-571',
#  'hsa-miR-602': 'mir-602',
#  'hsa-miR-1912': 'mir-1912',
#  'hsa-miR-1468': 'mir-1468',
#  'hsa-miR-606': 'mir-606',
#  'hsa-miR-1180': 'mir-1180',
#  'hsa-miR-623': 'mir-623',
#  'hsa-miR-1261': 'mir-1261',
#  'hsa-miR-596': 'mir-596',
#  'hsa-miR-3130-1': 'mir-3130',
#  'hsa-miR-3130-2': 'mir-3130',
#  'hsa-miR-3202-1': 'mir-3202',
#  'hsa-miR-3202-2': 'mir-3202',
#  'hsa-miR-1270': 'mir-1270',
#  'hsa-miR-3156-1': 'mir-3156',
#  'hsa-miR-3156-2': 'mir-3156',
#  'hsa-miR-3156-3': 'mir-3156',
#  'hsa-miR-3180-1': 'mir-3180',
#  'hsa-miR-3180-2': 'mir-3180',
#  'hsa-miR-3180-3': 'mir-3180',
#  'hsa-miR-3180-4': 'mir-3180',
#  'hsa-miR-3180-5': 'mir-3180',
#  'hsa-miR-3179-1': 'mir-3179',
#  'hsa-miR-3179-2': 'mir-3179',
#  'hsa-miR-3179-3': 'mir-3179',
#  'hsa-miR-3179-4': 'mir-3179',
#  'hsa-miR-1538': 'mir-1538',
#  'hsa-miR-1537': 'mir-1537',
#  'hsa-miR-4283-1': 'mir-4283',
#  'hsa-miR-4283-2': 'mir-4283',
#  'hsa-miR-1228': 'mir-1228',
#  'hsa-miR-2355': 'mir-2355',
#  'hsa-miR-647': 'mir-647',
#  'hsa-miR-1238': 'mir-1238',
#  'hsa-miR-1268a': 'mir-1268',
#  'hsa-miR-2861': 'mir-2861',
#  'hsa-miR-1305': 'mir-1305',
#  'hsa-miR-1252': 'mir-1252',
#  'hsa-miR-3119-1': 'mir-3119',
#  'hsa-miR-3119-2': 'mir-3119',
#  'hsa-miR-608': 'mir-608',
#  'hsa-miR-1909': 'mir-1909',
#  'hsa-miR-1469': 'mir-1469',
#  'hsa-miR-921': 'mir-921',
#  'hsa-miR-1269a': 'mir-1269',
#  'hsa-miR-1910': 'mir-1910',
#  'hsa-miR-1257': 'mir-1257',
#  'hsa-miR-3116-1': 'mir-3116',
#  'hsa-miR-3116-2': 'mir-3116',
#  'hsa-miR-1913': 'mir-1913',
#  'hsa-miR-1260a': 'mir-1260a',
#  'hsa-miR-1908': 'mir-1908',
#  'hsa-miR-1972-1': 'mir-1972',
#  'hsa-miR-1972-2': 'mir-1972',
#  'hsa-miR-5708': 'mir-1972',
#  'hsa-miR-3199-1': 'mir-3199',
#  'hsa-miR-3199-2': 'mir-3199',
#  'hsa-miR-3160-1': 'mir-3160',
#  'hsa-miR-3160-2': 'mir-3160',
#  'hsa-miR-4315-1': 'mir-4315',
#  'hsa-miR-4315-2': 'mir-4315',
#  'hsa-miR-1200': 'mir-1200',
#  'hsa-miR-1915': 'mir-1915',
#  'hsa-miR-1914': 'mir-1914',
#  'hsa-miR-1304': 'mir-1304',
#  'hsa-miR-3158-1': 'mir-3158',
#  'hsa-miR-3158-2': 'mir-3158',
#  'hsa-miR-1471': 'mir-1471',
#  'hsa-miR-3150a': 'mir-3150',
#  'hsa-miR-3150b': 'mir-3150',
#  'hsa-miR-3074': 'mir-3074',
#  'hsa-miR-3065': 'mir-3065',
#  'hsa-miR-3926-1': 'mir-3926',
#  'hsa-miR-3926-2': 'mir-3926',
#  'hsa-miR-3913-1': 'mir-3913',
#  'hsa-miR-3913-2': 'mir-3913',
#  'hsa-miR-3689a': 'mir-3689',
#  'hsa-miR-3689b': 'mir-3689',
#  'hsa-miR-3689c': 'mir-3689',
#  'hsa-miR-3689d-1': 'mir-3689',
#  'hsa-miR-3689d-2': 'mir-3689',
#  'hsa-miR-3689e': 'mir-3689',
#  'hsa-miR-3689f': 'mir-3689',
#  'hsa-miR-3910-1': 'mir-3910',
#  'hsa-miR-3910-2': 'mir-3910',
#  'hsa-miR-3914-1': 'mir-3914',
#  'hsa-miR-3914-2': 'mir-3914',
#  'hsa-miR-3622a': 'mir-3622',
#  'hsa-miR-3622b': 'mir-3622',
#  'hsa-miR-1343': 'mir-1343',
#  'hsa-miR-4509-1': 'mir-4509',
#  'hsa-miR-4509-2': 'mir-4509',
#  'hsa-miR-4509-3': 'mir-4509',
#  'hsa-miR-4776-1': 'mir-4776',
#  'hsa-miR-4776-2': 'mir-4776',
#  'hsa-miR-3198-1': 'mir-3198',
#  'hsa-miR-3198-2': 'mir-3198',
#  'hsa-miR-3135a': 'mir-3135',
#  'hsa-miR-3135b': 'mir-3135',
#  'hsa-miR-4435-1': 'mir-4435',
#  'hsa-miR-4435-2': 'mir-4435',
#  'hsa-miR-4679-1': 'mir-4679',
#  'hsa-miR-4679-2': 'mir-4679',
#  'hsa-miR-4650-1': 'mir-4650',
#  'hsa-miR-4650-2': 'mir-4650',
#  'hsa-miR-4436a': 'mir-4436',
#  'hsa-miR-4436b-1': 'mir-4436',
#  'hsa-miR-4436b-2': 'mir-4436',
#  'hsa-miR-3064': 'mir-3064',
#  'hsa-miR-3155a': 'mir-3155',
#  'hsa-miR-3155b': 'mir-3155',
#  'hsa-miR-4662a': 'mir-4662',
#  'hsa-miR-4662b': 'mir-4662',
#  'hsa-miR-4773-1': 'mir-4773',
#  'hsa-miR-4773-2': 'mir-4773',
#  'hsa-miR-3190': 'mir-3190',
#  'hsa-miR-3191': 'mir-3190',
#  'hsa-miR-4659a': 'mir-4659',
#  'hsa-miR-4659b': 'mir-4659',
#  'hsa-miR-4771-1': 'mir-4771',
#  'hsa-miR-4771-2': 'mir-4771',
#  'hsa-miR-3529': 'mir-3529',
#  'hsa-miR-3688-1': 'mir-3688',
#  'hsa-miR-3688-2': 'mir-3688',
#  'hsa-miR-3960': 'mir-3960',
#  'hsa-miR-4520-1': 'mir-4520',
#  'hsa-miR-4520-2': 'mir-4520',
#  'hsa-miR-4477a': 'mir-4477',
#  'hsa-miR-4477b': 'mir-4477',
#  'hsa-miR-1231': 'mir-1231',
#  'hsa-miR-4444-1': 'mir-4444',
#  'hsa-miR-4444-2': 'mir-4444',
#  'hsa-miR-4536-1': 'mir-4536',
#  'hsa-miR-4536-2': 'mir-4536',
#  'hsa-miR-5701-1': 'mir-5701',
#  'hsa-miR-5701-2': 'mir-5701',
#  'hsa-miR-4524a': 'mir-4524',
#  'hsa-miR-4524b': 'mir-4524',
#  'hsa-miR-3680-1': 'mir-3680',
#  'hsa-miR-3680-2': 'mir-3680',
#  'hsa-miR-3670-1': 'mir-3670',
#  'hsa-miR-3670-2': 'mir-3670',
#  'hsa-miR-3670-3': 'mir-3670',
#  'hsa-miR-3670-4': 'mir-3670',
#  'hsa-miR-5681a': 'mir-5681',
#  'hsa-miR-5681b': 'mir-5681',
#  'hsa-miR-5692a-1': 'mir-5692',
#  'hsa-miR-5692a-2': 'mir-5692',
#  'hsa-miR-5692c-1': 'mir-5692',
#  'hsa-miR-5692c-2': 'mir-5692',
#  'hsa-miR-5583-1': 'mir-5583',
#  'hsa-miR-5583-2': 'mir-5583',
#  'hsa-miR-1260b': 'mir-1260b',
#  'hsa-miR-6511a-1': 'mir-6511',
#  'hsa-miR-6511a-2': 'mir-6511',
#  'hsa-miR-6511a-3': 'mir-6511',
#  'hsa-miR-6511a-4': 'mir-6511',
#  'hsa-miR-6511b-1': 'mir-6511',
#  'hsa-miR-6511b-2': 'mir-6511',
#  'hsa-miR-3173': 'mir-3173',
#  'hsa-miR-4743': 'mir-4743',
#  'hsa-miR-4446': 'mir-4446',
#  'hsa-miR-3154': 'mir-3154',
#  'hsa-miR-4667': 'mir-4667',
#  'hsa-miR-3151': 'mir-3151',
#  'hsa-miR-3660': 'mir-3660',
#  'hsa-miR-2110': 'mir-2110',
#  'hsa-miR-3943': 'mir-3943',
#  'hsa-miR-3193': 'mir-3193',
#  'hsa-miR-4796': 'mir-4796',
#  'hsa-miR-6127': 'mir-6127',
#  'hsa-miR-3613': 'mir-3613',
#  'hsa-miR-6131': 'mir-6131',
#  'hsa-miR-6130': 'mir-6130',
#  'hsa-miR-6133': 'mir-6133',
#  'hsa-miR-3121': 'mir-3121',
#  'hsa-miR-6129': 'mir-6129',
#  'hsa-miR-3145': 'mir-3145',
#  'hsa-miR-3138': 'mir-3138',
#  'hsa-miR-23c': 'mir-23c',
#  'hsa-miR-6132': 'mir-6132',
#  'hsa-miR-3127': 'mir-3127',
#  'hsa-miR-4484': 'mir-4484',
#  'hsa-miR-3200': 'mir-3200',
#  'hsa-miR-6128': 'mir-6128',
#  'hsa-miR-6134': 'mir-6134',
#  'hsa-miR-4529': 'mir-4529',
#  'hsa-miR-3129': 'mir-3129',
#  'hsa-miR-4660': 'mir-4660',
#  'hsa-miR-3927': 'mir-3927',
#  'hsa-miR-378j': 'mir-378_2',
#  'hsa-miR-2114': 'mir-2114',
#  'hsa-miR-4510': 'mir-4510',
#  'hsa-miR-4429': 'mir-4429',
#  'hsa-miR-4716': 'mir-4716',
#  'hsa-miR-3617': 'mir-3617',
#  'hsa-miR-1273c': 'mir-1273c',
#  'hsa-miR-3188': 'mir-3188',
#  'hsa-miR-3937': 'mir-3937',
#  'hsa-miR-3117': 'mir-3117',
#  'hsa-miR-4654': 'mir-4654',
#  'hsa-miR-4504': 'mir-4504',
#  'hsa-miR-3132': 'mir-3132',
#  'hsa-miR-6089-1': 'mir-6089',
#  'hsa-miR-6089-2': 'mir-6089',
#  'hsa-miR-4803': 'mir-4803',
#  'hsa-miR-4515': 'mir-4515',
#  'hsa-miR-3664': 'mir-3664',
#  'hsa-miR-3612': 'mir-3612',
#  'hsa-miR-3938': 'mir-3938',
#  'hsa-miR-4738': 'mir-4738',
#  'hsa-miR-2278': 'mir-2278',
#  'hsa-miR-3126': 'mir-3126',
#  'hsa-miR-3923': 'mir-3923',
#  'hsa-miR-4791': 'mir-4791',
#  'hsa-miR-3661': 'mir-3661',
#  'hsa-miR-3615': 'mir-3615',
#  'hsa-miR-4526': 'mir-4526',
#  'hsa-miR-4782': 'mir-4782',
#  'hsa-miR-4421': 'mir-4421',
#  'hsa-miR-6500': 'mir-4421',
#  'hsa-miR-3122': 'mir-3122',
#  'hsa-miR-4672': 'mir-4672',
#  'hsa-miR-4742': 'mir-4742',
#  'hsa-miR-629': 'mir-629',
#  'hsa-miR-3607': 'mir-3607',
#  'hsa-miR-3174': 'mir-3174',
#  'hsa-miR-4788': 'mir-4788',
#  'hsa-miR-4798': 'mir-4798',
#  'hsa-miR-3136': 'mir-3136',
#  'hsa-miR-4774': 'mir-4774',
#  'hsa-miR-4451': 'mir-4451',
#  'hsa-miR-3934': 'mir-3934',
#  'hsa-miR-4637': 'mir-4637',
#  'hsa-miR-4423': 'mir-4423',
#  'hsa-miR-3192': 'mir-3192',
#  'hsa-miR-3940': 'mir-3940',
#  'hsa-miR-3912': 'mir-3912',
#  'hsa-miR-2392': 'mir-2392',
#  'hsa-miR-3140': 'mir-3140',
#  'hsa-miR-3690-1': 'mir-3690',
#  'hsa-miR-3690-2': 'mir-3690',
#  'hsa-miR-4488': 'mir-4488',
#  'hsa-miR-3146': 'mir-3146',
#  'hsa-miR-4428': 'mir-4428',
#  'hsa-miR-1976': 'mir-1976',
#  'hsa-miR-3165': 'mir-3165',
#  'hsa-miR-3170': 'mir-3170',
#  'hsa-miR-3605': 'mir-3605',
#  'hsa-miR-4427': 'mir-4427',
#  'hsa-miR-1199': 'mir-1199',
#  'hsa-miR-6516': 'mir-6516',
#  'hsa-miR-6770-1': 'mir-6770',
#  'hsa-miR-6770-2': 'mir-6770',
#  'hsa-miR-6770-3': 'mir-6770',
#  'hsa-miR-7973-1': 'mir-7973',
#  'hsa-miR-7973-2': 'mir-7973',
#  'hsa-miR-6859-1': 'mir-6859',
#  'hsa-miR-6859-2': 'mir-6859',
#  'hsa-miR-6859-3': 'mir-6859',
#  'hsa-miR-6859-4': 'mir-6859',
#  'hsa-miR-6715a': 'mir-6715',
#  'hsa-miR-3618': 'mir-3618',
#  'hsa-miR-6794': 'mir-6794',
#  'hsa-miR-6827': 'mir-6827',
#  'hsa-miR-5697': 'mir-5697',
#  'hsa-miR-4703': 'mir-4703',
#  'hsa-miR-4766': 'mir-4766',
#  'hsa-miR-1911': 'mir-1911',
#  'hsa-miR-8071-1': 'mir-8071',
#  'hsa-miR-8071-2': 'mir-8071',
#  'hsa-miR-6505': 'mir-6505',
#  'hsa-miR-6790': 'mir-6790',
#  'hsa-miR-1243': 'mir-1243',
#  'hsa-miR-3167': 'mir-3167',
#  'hsa-miR-7641-1': 'mir-7641',
#  ...}

# %%
df[df.mirna_family.isna()]
# Out:
#            mirna_name mirna_accession                  sequence mirna_family  \
# 37     hsa-miR-101-3p    MIMAT0000099     TTCAGTTATCACAGTACTGTA          NaN
# 56       hsa-miR-7-5p    MIMAT0000252  AACAACAAAATCACTAGTCTTCCA          NaN
# 65     hsa-miR-183-5p    MIMAT0000261    AGTGAATTCTACCAGTGCCATA          NaN
# 68    hsa-miR-203a-3p    MIMAT0000264    CTAGTGGTCCTAAACATTTCAC          NaN
# 78     hsa-miR-217-5p    MIMAT0000274   TCCAATCAGTTCCTGATGCAGTA          NaN
# ...               ...             ...                       ...          ...
# 2651    hsa-miR-12131    MIMAT0049025      TGGGAGTACACCTCTCCAAA          NaN
# 2652    hsa-miR-12132    MIMAT0049026    CATCATAATTCTCACAGTAATA          NaN
# 2653    hsa-miR-12133    MIMAT0049027    TGTACTTTTTAATGGTGCCAAG          NaN
# 2654    hsa-miR-12135    MIMAT0049031        TTTACAAACAAACCTTTA          NaN
# 2655    hsa-miR-12136    MIMAT0049032        GGCCTCCATGACTTTTTC          NaN
#
#       conservation
# 37             2.0
# 56             2.0
# 65             2.0
# 68             2.0
# 78             2.0
# ...            ...
# 2651          -1.0
# 2652           2.0
# 2653           2.0
# 2654          -1.0
# 2655          -1.0
#
# [142 rows x 5 columns]

# %%
df["new_families"] = df["mirna_name"].map(precursor_families)

# Concatenate "_mircarta" to non-na values in 'new_families' column
df['new_families'] = df['new_families'].apply(
    lambda x: f"{x}_mircarta" if pd.notna(x) else x
)

# Append non-na values from 'new_families' to na rows in 'mirna_family'
df['mirna_family'] = df['mirna_family'].fillna(df['new_families'])

# %%
# predict mirna_family name from mirna_name and add _pred suffix to all
df['mirna_name_pred'] = df['mirna_name'].str.split('-', expand=True)[1] + '-' + df['mirna_name'].str.split('-', expand=True)[2] + '_pred'

# append to family col
df['mirna_family'] = df['mirna_family'].combine_first(df['mirna_name_pred'])

df.drop(columns=["new_families",'mirna_name_pred'], inplace=True)

# %%
df.isna().sum()
# Out:
# mirna_name         0
# mirna_accession    0
# sequence           0
# mirna_family       0
# conservation       0
# dtype: int64

# %%
df.to_csv('mirna.csv', index=False)
